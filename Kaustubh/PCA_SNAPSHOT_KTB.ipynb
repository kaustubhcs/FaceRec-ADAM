# %%
# Loading and displaying an image
from PIL import Image
img = Image.open('/home/ktb/git/FaceRec-ADAM/Kaustubh/data/orl/s1/1.pgm')
print(img.format, img.size, img.mode)
display(img)
# Out:
# PPM (92, 112) L
# <PIL.PpmImagePlugin.PpmImageFile image mode=L size=92x112 at 0x7FAD7D261C50>

# %%
# Creating training, validation and test datasets
import os
import shutil

def copy_data(dir_s, fname):
    os.chdir(dir_s + '/' + fname)
    dir_train = dir_s + '/train/' + fname
    dir_valid = dir_s + '/valid/' + fname
    dir_test = dir_s + '/test/' + fname
    if not os.path.exists(dir_train):
        os.makedirs(dir_train)
    if not os.path.exists(dir_valid):
        os.makedirs(dir_valid)
    if not os.path.exists(dir_test):
        os.makedirs(dir_test)
    i = 1
    for filename in os.listdir(dir_s + '/' + fname):
        if i <= 6:
            shutil.copy(dir_s + '/' + fname + '/' + str(i) + '.pgm', dir_train)
        elif i <= 8:
            shutil.copy(dir_s + '/' + fname + '/' + str(i) + '.pgm', dir_valid)
        else:
            shutil.copy(dir_s + '/' + fname + '/' + str(i) + '.pgm', dir_test)
        i = i + 1

dir_src = '/home/ktb/git/FaceRec-ADAM/Kaustubh/data/orl'
os.chdir(dir_src)
for filename in os.listdir(dir_src):
    if filename.startswith('s'):
        copy_data(dir_src, filename)
print('Separated Training, Validation and Test Data')
# Out:
# Separated Training, Validation and Test Data

# %%
# Assign Labels
def assign_addr_label(path):
    dirs = os.listdir(path)
    addrs = []
    labels = []
    for d in dirs:
        os.chdir(path + '/' + d)
        addr = glob.glob(path + '/' + d + '/' + '*')
        label = [d for i in range(len(addr))]
        addrs.extend(addr)
        labels.extend(label)
    return list(zip(addrs, labels))

import glob
train_path = '/home/ktb/git/FaceRec-ADAM/Kaustubh/data/orl/train'
train_data = assign_addr_label(train_path)
train_addrs, train_labels = zip(*train_data)
valid_path = '/home/ktb/git/FaceRec-ADAM/Kaustubh/data/orl/valid'
valid_data = assign_addr_label(valid_path)
valid_addrs, valid_labels = zip(*valid_data)
test_path = '/home/ktb/git/FaceRec-ADAM/Kaustubh/data/orl/test'
test_data = assign_addr_label(test_path)
test_addrs, test_labels = zip(*test_data)
print('Assigned Labels to Training, Validation and Test Data')
# Out:
# Assigned Labels to Training, Validation and Test Data

# %%
# Load images and save them
import numpy as np
train_storage = []
valid_storage = []
test_storage = []
mean_storage = []
# Training Images
for i in range(len(train_addrs)):
    if i % 20 == 0 and i > 1:
        print('Train data: {}/{}'.format(i, len(train_addrs)))
    addr = train_addrs[i]
    img = Image.open(addr)
    img = np.array(img)
    train_storage.append(img)
    # print(np.array(img))
    mean_storage.append(np.sum(img) / float(len(train_labels)))
# print(train_storage)
# Validation Images
for i in range(len(valid_addrs)):
    if i % 20 == 0 and i > 1:
        print('Valid data: {}/{}'.format(i, len(valid_addrs)))
    addr = valid_addrs[i]
    img = Image.open(addr)
    img = np.array(img)
    valid_storage.append(img)
    # print(np.array(img))
# print(valid_storage)
# Test Images
for i in range(len(test_addrs)):
    if i % 20 == 0 and i > 1:
        print('Test data: {}/{}'.format(i, len(test_addrs)))
    addr = test_addrs[i]
    img = Image.open(addr)
    img = np.array(img)
    test_storage.append(img)
    # print(np.array(img))
# print(test_storage)
# Out:
# Train data: 20/240
# Train data: 40/240
# Train data: 60/240
# Train data: 80/240
# Train data: 100/240
# Train data: 120/240
# Train data: 140/240
# Train data: 160/240
# Train data: 180/240
# Train data: 200/240
# Train data: 220/240
# Valid data: 20/80
# Valid data: 40/80
# Valid data: 60/80
# Test data: 20/80
# Test data: 40/80
# Test data: 60/80

# %%
# Combine data and labels
train_set = list(zip(train_storage, train_labels))
valid_set = list(zip(valid_storage, valid_labels))
test_set = list(zip(test_storage, test_labels))

# %%
# Principal Component Analysis by Snapshot method
# Converting images to a one-dimensional vector
train_1d = [t.flatten() for t in train_storage]
# Calculate the mean image
mean = np.sum(train_1d, axis = 0) / len(train_1d)
# print(mean)
# Mean-centering the images
train_center = [t - mean for t in train_1d]
# print(train_center)
# Create data matrix
data_matrix = np.transpose(train_center)
# print(np.transpose(train_center))
# Create covariance matrix
covariance = np.dot(np.transpose(data_matrix), data_matrix)
# Check for symmetricity
if(covariance.all() == np.transpose(covariance).all()):
    print('Symmetric')
# Out:
# Symmetric

# %%
# Compute eigenvalues and eigenvectors of covariance matrix
eig_values, eig_vectors = np.linalg.eig(covariance)
# print(eig_values)

# %%
# Multiply data matrix by the eigenvectors
v_cap = np.dot(data_matrix, eig_vectors)
# Divide the eigen vectors by their norm
tr_v_cap = np.transpose(v_cap)
v_n = [a / np.linalg.norm(a) for a in tr_v_cap]

# %%
# Sort eigenvalues and eigenvectors
eig = list(zip(eig_values, v_n))
sorted(eig, key=lambda x: x[0], reverse = True)
print('Sorted eigen values and eigen vectors from high to low')
# Out:
# Sorted eigen values and eigen vectors from high to low

# %%
# Remove close to zero eigen values and their corresponding eigen vectors
eig_values, v_n = zip(*eig)
temp_values = []
temp_vectors = []
for e in eig_values:
    if e.real < 0.000001:
        pass
    else:
        temp_values.append(e)
        idx = eig_values.index(e)
        temp_vectors.append(v_n[idx])
eig_values, v_n = temp_values, temp_vectors
eig = list(zip(eig_values, v_n))

# %%
# Create projection matrix
V = np.transpose(v_n)

# %%
# Project training images into subspace
proj_data_matrix = np.dot(v_n, data_matrix)

# %%
# Identify test images
# Test images are mean-centered
valid_1d = [t.flatten() for t in valid_storage]
# Mean-center the images
valid_center = [t - mean for t in valid_1d]
# Create data matrix
valid_data_matrix = np.transpose(valid_center)
# Project test images into the same subspace as training images
proj_valid_matrix = np.dot(v_n, valid_data_matrix)

# %%
# Calculate L2 norms
tr1 = np.transpose(proj_valid_matrix)
tr2 = np.transpose(proj_data_matrix)
l2 = []
for a in tr1:
    l1 = [np.linalg.norm(a - b) for b in tr2]
    l2.append(l1)

# %%
# Find the index of the training image that matches closely with the test image
idx = [l.index(min(l)) for l in l2]

# %%
# Find the label for the test images
out = []
for i in idx:
    out.append(train_labels[i])
# print(list(zip(out, idx)))
# print(list(zip(valid_labels, idx)))

# %%
# Find the accuracy
correct = 0
for i in range(len(out)):
    if out[i] == valid_labels[i]:
        correct += 1
accuracy = correct * 100 / len(out)
print('Accuracy(%): ' + str(accuracy))
# Out:
# Accuracy(%): 93.75

# %%
# Identify test images
# Test images are mean-centered
test_1d = [t.flatten() for t in test_storage]
# Mean-center the images
test_center = [t - mean for t in test_1d]
# Create data matrix
test_data_matrix = np.transpose(test_center)
# Project test images into the same subspace as training images
proj_test_matrix = np.dot(v_n, test_data_matrix)

# %%
# Calculate L2 norms
tr1 = np.transpose(proj_test_matrix)
tr2 = np.transpose(proj_data_matrix)
l2 = []
for a in tr1:
    l1 = [np.linalg.norm(a - b) for b in tr2]
    l2.append(l1)

# %%
# Find the index of the training image that matches closely with the test image
idx = [l.index(min(l)) for l in l2]

# %%
# Find the label for the test images
out = []
for i in idx:
    out.append(train_labels[i])

# %%
# Find the accuracy
correct = 0
for i in range(len(out)):
    if out[i] == test_labels[i]:
        correct += 1
accuracy = correct * 100 / len(out)
print('Accuracy(%): ' + str(accuracy))
# Out:
# Accuracy(%): 93.75

# %%
# Print images (true / predicted)
j = 0
for i in range(len(out)):
    dis1 = Image.fromarray(train_storage[idx[i]])
    display(dis1)
    print('Predicted:' + str(out[i]))
    dis2 = Image.fromarray(test_storage[j])
    display(dis2)
    print('True:' + str(test_labels[j]))
    print('-----------------------------------')
    j += 1
# print(list(zip(out, idx)))
# print(list(zip(test_labels, idx)))
# Out:
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121EF0>
# Predicted:s29
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B38>
# True:s29
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121CC0>
# Predicted:s29
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B70>
# True:s29
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121D30>
# Predicted:s2
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121A90>
# True:s2
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121A58>
# Predicted:s2
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B70>
# True:s2
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B00>
# Predicted:s14
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121A90>
# True:s14
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121BE0>
# Predicted:s14
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B70>
# True:s14
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B00>
# Predicted:s21
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121E80>
# True:s21
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121BE0>
# Predicted:s21
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B70>
# True:s21
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B00>
# Predicted:s26
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121E80>
# True:s26
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121BE0>
# Predicted:s26
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B70>
# True:s26
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B00>
# Predicted:s17
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121E80>
# True:s17
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121BE0>
# Predicted:s17
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B70>
# True:s17
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B00>
# Predicted:s40
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121E80>
# True:s5
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# Predicted:s5
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121BE0>
# True:s5
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B00>
# Predicted:s27
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121E80>
# True:s27
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# Predicted:s27
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B70>
# True:s27
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121BE0>
# Predicted:s23
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B00>
# True:s23
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121E80>
# Predicted:s23
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# True:s23
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B70>
# Predicted:s5
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121BE0>
# True:s40
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B00>
# Predicted:s5
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# True:s40
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# Predicted:s35
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121BE0>
# True:s35
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C13DDD8>
# Predicted:s35
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# True:s35
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# Predicted:s8
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121BE0>
# True:s8
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9AC400>
# Predicted:s8
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# True:s8
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9ACA20>
# Predicted:s24
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C13DDD8>
# True:s24
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B00>
# Predicted:s24
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9ACB38>
# True:s24
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# Predicted:s12
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C13DDD8>
# True:s12
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9AC710>
# Predicted:s12
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s12
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# Predicted:s6
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9ACF28>
# True:s6
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9AC320>
# Predicted:s6
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s6
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9AC550>
# Predicted:s3
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B00>
# True:s3
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9AC048>
# Predicted:s3
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s3
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9AC550>
# Predicted:s15
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B00>
# True:s15
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C13DDD8>
# Predicted:s15
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9AC9B0>
# True:s15
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# Predicted:s16
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s16
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9AC4A8>
# Predicted:s16
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B00>
# True:s16
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C13DDD8>
# Predicted:s39
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9AC208>
# True:s39
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# Predicted:s39
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s39
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9AC390>
# Predicted:s28
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B00>
# True:s28
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C13DDD8>
# Predicted:s28
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9AC470>
# True:s28
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121B00>
# Predicted:s1
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s1
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9AC3C8>
# Predicted:s1
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121D30>
# True:s1
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# Predicted:s38
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s10
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C13DDD8>
# Predicted:s10
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121D30>
# True:s10
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C747B38>
# Predicted:s11
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s11
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C13DDD8>
# Predicted:s11
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121D30>
# True:s11
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C747B38>
# Predicted:s7
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s7
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A60F0>
# Predicted:s7
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121D30>
# True:s7
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A6240>
# Predicted:s36
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s36
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# Predicted:s36
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A6080>
# True:s36
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A6668>
# Predicted:s33
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s33
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A6048>
# Predicted:s33
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A6518>
# True:s33
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# Predicted:s32
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A6128>
# True:s32
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A64E0>
# Predicted:s32
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s32
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A6630>
# Predicted:s34
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A6128>
# True:s34
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# Predicted:s34
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s34
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A6630>
# Predicted:s4
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121D30>
# True:s4
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035390>
# Predicted:s4
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s4
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# Predicted:s9
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A6128>
# True:s9
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035470>
# Predicted:s9
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C72E7F0>
# True:s9
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035390>
# Predicted:s25
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A6128>
# True:s25
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121F98>
# Predicted:s25
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035470>
# True:s25
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121D30>
# Predicted:s22
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A6128>
# True:s22
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C0356D8>
# Predicted:s22
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C0355C0>
# True:s22
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C121D30>
# Predicted:s37
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C0357F0>
# True:s37
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035668>
# Predicted:s37
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C9A6128>
# True:s37
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C0355C0>
# Predicted:s18
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C0357F0>
# True:s18
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C0357B8>
# Predicted:s18
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035860>
# True:s18
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035780>
# Predicted:s31
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035940>
# True:s31
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C0358D0>
# Predicted:s31
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C0359B0>
# True:s31
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035978>
# Predicted:s19
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C0359E8>
# True:s19
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035940>
# Predicted:s15
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035A20>
# True:s19
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035780>
# Predicted:s20
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035A58>
# True:s20
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C0359E8>
# Predicted:s20
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035B00>
# True:s20
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C0359B0>
# Predicted:s30
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035BE0>
# True:s30
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035BA8>
# Predicted:s30
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035A20>
# True:s30
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035C88>
# Predicted:s38
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035CC0>
# True:s38
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C0359E8>
# Predicted:s38
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035C50>
# True:s38
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035D68>
# Predicted:s13
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035DD8>
# True:s13
# -----------------------------------
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C035CF8>
# Predicted:s13
# <PIL.Image.Image image mode=L size=92x112 at 0x7FAD7C0359E8>
# True:s13
# -----------------------------------

# %%
# Write PCA output vectors to file

## Train Data
f = open('/home/ktb/git/FaceRec-ADAM/Kaustubh/data/pca_train_data_with_labels.txt', 'w+')
f.write('Training data\n')
train_file = zip(np.transpose(proj_data_matrix), train_labels)
for i in train_file:
    f.write(str(i))

## Train Data
f = open('/home/ktb/git/FaceRec-ADAM/Kaustubh/data/pca_valid_data_with_labels.txt', 'w+')
f.write('Validation data\n')
valid_file = zip(np.transpose(proj_valid_matrix), valid_labels)
for i in valid_file:
    f.write(str(i))

## Train Data
f = open('/home/ktb/git/FaceRec-ADAM/Kaustubh/data/pca_test_data_with_labels.txt', 'w+')
f.write('\nTest data\n')
test_file = zip(np.transpose(proj_test_matrix), test_labels)
for i in test_file:
    f.write(str(i))

print ('Program Completed')
# Out:
# Program Completed

# %%
proj_data_matrix.shape
# Out:
# (239, 240)

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn import datasets
from sklearn import svm

# %%
clf = svm.SVC(gamma=0.0001, C=100)

x,y = np.transpose(proj_data_matrix[:]),train_labels[:],

clf.fit(x,y)
# dat_predict = digits.data[-1]
# dat_predict.reshape(-1,1)
#print ('Prediction: ', clf.predict(np.reshape(digits.data[-1], (1,-1))))
print ('Prediction: ', clf.predict(np.reshape(proj_data_matrix[-1], (1,-1) )))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-07bfeb529162> in <module>()
#       3 x,y = (proj_data_matrix[:]),train_labels[:],
#       4
# ----> 5 clf.fit(x,y)
#       6 # dat_predict = digits.data[-1]
#       7 # dat_predict.reshape(-1,1)
#
# /home/hemnaniv/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# /home/hemnaniv/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     581         y = y.astype(np.float64)
#     582
# --> 583     check_consistent_length(X, y)
#     584
#     585     return X, y
#
# /home/hemnaniv/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [239, 240]
